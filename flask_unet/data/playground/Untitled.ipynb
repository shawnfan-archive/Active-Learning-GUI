# %%
from skimage.transform import resize
import os
import numpy as np
import seaborn as sns

# %%
some_corr = np.load("2020_6_27_20_0/corr/89.npy")

# %%
sns.heatmap(some_corr)

# %%
resized_corr = resize(some_corr, (28,28), 
                      mode='reflect',
                   preserve_range=True,
                   order=0,
                   anti_aliasing=False)

# %%
sns.heatmap(resized_corr)

# %%
some_corr = np.load("2020_6_27_20_0/maps/99.npy")

# %%
sns.heatmap(some_corr)

# %%
some_img = np.load("2020_6_27_20_0/images/img_99.npy")

# %%
sns.heatmap(some_img)
